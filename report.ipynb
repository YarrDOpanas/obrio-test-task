# %%
from app_store_scraper import AppStore
import pandas as pd
from textblob import TextBlob
from collections import Counter
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
import matplotlib.pyplot as plt
import seaborn as sns
import os
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yaroslavopanasenko/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/yaroslavopanasenko/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
def preprocess_data(reviews):
    df = pd.DataFrame(reviews)
    df["cleaned_review"] = df["review"].str.lower().str.replace(r'[^\w\s]', '')
    return df

def calculate_metrics(data):
    avg_rating = data["rating"].mean()
    rating_dist = data["rating"].value_counts(normalize=True) * 100
    return {
        "average_rating": str(avg_rating),
        "rating_distribution": rating_dist.to_dict()
    }

def generate_csv(reviews):
    df = pd.DataFrame(reviews)
    file_path = os.path.join("reports", "reviews.csv")
    df.to_csv(file_path, index=False)
    return file_path

def fetch_reviews(app_name, app_id, country='us', num_reviews=100):
    app = AppStore(country=country, app_name = app_name, app_id = app_id)
    app.review(how_many=num_reviews)
    return app.reviews

# %%
def analyze_sentiment(reviews):
    sentiment_results = []
    for review in reviews:
        analysis = TextBlob(review["cleaned_review"])
        polarity = analysis.sentiment.polarity
        sentiment = "positive" if polarity > 0 else "negative" if polarity < 0 else "neutral"
        sentiment_results.append({
            "title": review["title"],
            "sentiment": sentiment,
            "review": review["review"],
            "cleaned_review": review["cleaned_review"]
        })
    return sentiment_results

def generate_insights(reviews):
    negative_reviews = [review["cleaned_review"] for review in analyze_sentiment(reviews) if review["sentiment"] == "negative"]
    
    # Tokenize and extract common words
    all_words = []
    for review in negative_reviews:
        words = word_tokenize(review.lower())
        words = [word for word in words if word.isalpha() and word not in ["the", "and", "is", "to", "a", "of", "in"]]
        all_words.extend(words)
    
    word_counts = Counter(all_words)
    common_issues = word_counts.most_common(5)
    
    suggestions = []
    issue_mapping = {
        "slow": "Enhance app performance to improve user experience.",
        "lag": "Enhance app performance to improve user experience.",
        "performance": "Enhance app performance to improve user experience.",
        "crash": "Fix bugs and stability issues to prevent crashes.",
        "bug": "Fix bugs and stability issues to prevent crashes.",
        "error": "Fix bugs and stability issues to prevent crashes.",
        "design": "Improve the user interface for better usability.",
        "ui": "Improve the user interface for better usability.",
        "layout": "Improve the user interface for better usability.",
        "support": "Enhance customer support responsiveness.",
        "help": "Enhance customer support responsiveness.",
        "customer": "Enhance customer support responsiveness.",
        "battery": "Optimize battery consumption for efficiency.",
        "drain": "Optimize battery consumption for efficiency.",
        "power": "Optimize battery consumption for efficiency."
    }
    
    for word, _ in common_issues:
        if word in issue_mapping:
            suggestions.append(issue_mapping[word])
    
    insights = {
        "common_negative_phrases": common_issues,
        "suggested_improvements": list(set(suggestions))
    }
    
    return insights

# %%
def generate_visualizations(data):
    os.makedirs("reports", exist_ok=True)
    
    # Rating Distribution
    plt.figure(figsize=(8, 6))
    sns.countplot(x=data['rating'], palette='viridis')
    plt.title("Rating Distribution")
    plt.xlabel("Rating")
    plt.ylabel("Count")
    plt.savefig("reports/rating_distribution.png")
    plt.close()
    
    # Sentiment Distribution
    plt.figure(figsize=(8, 6))
    sentiment_counts = data['sentiment'].value_counts()
    sentiment_counts.plot(kind='bar', color=['green', 'gray', 'red'])
    plt.title("Sentiment Distribution")
    plt.xlabel("Sentiment")
    plt.ylabel("Count")
    plt.savefig("reports/sentiment_distribution.png")
    plt.close()

# %%
def collect_reviews(app_name: str, app_id: str):
    reviews = fetch_reviews(app_name, app_id)
    return reviews


def get_metrics(app_name: str, app_id: str):
    reviews = fetch_reviews(app_name, app_id)
    data = preprocess_data(reviews)
    metrics = calculate_metrics(data)
    generate_visualizations(data)
    return {
        "metrics": metrics,
        "visualizations": {
            "rating_distribution": "reports/rating_distribution.png",
            "sentiment_distribution": "reports/sentiment_distribution.png"
        }
    }


def get_sentiments(app_name: str, app_id: str):
    reviews = fetch_reviews(app_name, app_id)
    sentiments = analyze_sentiment(reviews)
    return {"message": "Sentiment analysis completed", "sentiments": sentiments}


def download_reviews(app_name: str, app_id: str):
    reviews = fetch_reviews(app_name, app_id)
    csv_file = generate_csv(reviews)
    return {"message": "CSV generated successfully", "file_path": csv_file}


def get_insights(app_name: str, app_id: str):
    reviews = fetch_reviews(app_name, app_id)
    insights = generate_insights(reviews)
    return insights

# %%
app_name = "nebula-horoscope-astrology"
app_id = "1459969523"

reviews = collect_reviews(app_name, app_id)
reviews
# Out:
# 2025-01-31 16:27:45,147 [INFO] Base - Initialised: AppStore('us', 'nebula-horoscope-astrology', 1459969523)
# 2025-01-31 16:27:45,147 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/nebula-horoscope-astrology/id1459969523
# 2025-01-31 16:27:46,491 [INFO] Base - [id:1459969523] Fetched 100 reviews (100 fetched in total)
# [{'date': datetime.datetime(2019, 10, 5, 23, 30, 44),
#   'developerResponse': {'id': 11098150,
#    'body': 'Thanks for your review! 💖',
#    'modified': '2019-10-07T11:41:24Z'},
#   'review': "Crazy accurate!!! I am not sure who writes these or how they come up with them but it's almost crazy how accurate they are sometimes!! I'm usually not one of those swear by astrology sign type of people but this app really describes what I am going through most of the time and it gives you positive hope. And I even once had an appointment with an astrologer who was supposed to help me solve some of my personal issues, and that was of course a different experience. But for those who haven’t seen real astrologers, this app is the closest to it I’ve ever seen And I can tell you for sure that with the help of the stars you can find out the most important numbers in your life, which tattoo should people of your sign do, when is the best moon for a new haircut, and a lot more. And this app is great about it, it gives you so many tips from different parts of your life, that with the personal astrologer you’d have to pay a fortune for that! So this app ain’t be cheap, but the price for this detailed info is more than acceptable. But that’s only for people who care about real astrology, for those who should just read some random predictions, framed as your horoscope - go on with free apps. I don’t believe there would be people doing so much work to prepare horoscopes for free. So I definitely recommend this app to anyone I know who is at least a bit interested in astrology, thank you for making this app so great!",
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Anna',
#   'userName': 'Uz3-155-597'},
#  {'date': datetime.datetime(2019, 10, 5, 23, 27, 49),
#   'developerResponse': {'id': 11098037,
#    'body': "It's so kind of you, thanks for your review 💖",
#    'modified': '2019-10-07T11:36:32Z'},
#   'review': 'I really like getting my daily horoscope in this beautiful app and I absolutely love that this one has a daily reminder that lets you know not to forget to read your horoscope for that day .. And if you are so curious as I am you may sometimes read your horoscope for tomorrow, but I don’t recommend to do that. I prefer to read my horoscope in the evening, to analyze the whole day and to remember the details which my daily horoscope describes, it’s like you summarize your day and remember everything the most significant from it. Another way to have fun is that you can learn for instance how Moon in Libra, that is ending already, influences your life. You can learn that from astrology course inside an app.. And then you can discover what actually happens in your life and see this huge connection! Or you can learn about previous month and analyze it as well! And then you will be able to plan some important events by yourself, taking into account the planetary movement, you will choose the right time for some changes and for big decisions. Or you can just go for personal reading from astrologist, but this is more exciting for me. And so on, and so forth, I can actually tell a lot about this app. But you’d better try yourself. I highly recommend this app... The theme, the colors, daily reminder, and much more... Thank you for this app I rate it as 5 stars!!!',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Alex',
#   'userName': 'm8fjl5VA'},
#  {'date': datetime.datetime(2019, 10, 5, 23, 27, 35),
#   'developerResponse': {'id': 11098029,
#    'body': 'Appreciate your feedback 💖',
#    'modified': '2019-10-07T11:36:05Z'},
#   'review': 'Nothing but great things to say about this app! Accurate, honest and good intentions! It really makes me happy with all their caring notifications and so much interesting things to read in the app! I like the “Learn” section and the “Relationships”H section too. It’s just that every time I can’t wait to get access for the new lessons! This is so exciting and intriguing, I am studying astrology with an excitement like I am playing a game. And that is definitely a great way to study! However the love compatibility option needs to have gender options as masculine and feminine vibrations effect compatibility a lot! And that is not just about love compatibility, but also work, family, friendship, any relationship you may have with another person actually. Add gender options male female nonbinary and maybe a masculine/feminine chart for the non binary folks out there. Please consider this! This is actually really important right now. But as far as I know noone has actually done something like that, at least none of those apps that I’ve used before, and I am telling you this because I really like your app. And all the other features are absolutely great, that is the only thing I wanted you to consider. So think about it, if you do it your app will definitely be #1 among all the horoscope apps. So just keep rocking!',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Tanya',
#   'userName': 'Сцукатик'},
#  {'date': datetime.datetime(2024, 11, 22, 11, 43, 24),
#   'developerResponse': {'id': 48445622,
#    'body': "Hello dear user!  \n\xa0  \nThank you so much for updating your review and sharing your detailed feedback with us! We're thrilled to hear that your experience has improved and that you were able to find a psychic who truly resonated with you. Your insights are incredibly valuable, and we want to assure you that we’ve taken all your comments to heart, including suggestions about our screening process, app features, and pricing.\n\nIf you have any further questions or new concerns, please don’t hesitate to reach out to us at nebula.support@nebulahoroscope.com. We’ll do our absolute best to assist you as soon as possible!  \n  \nKind regards, Nebula team 🔮",
#    'modified': '2024-11-24T09:29:25Z'},
#   'review': 'I went through a bunch of psychics before i found one that was really legit.  Cost per minute in chat is total B.S. and very expensive. Some do not directly answer your questions and lead you with questions they offer.  I had the same woman for several weeks and she made stuff up in details to prolong the chat session.  It called her out on it and then there was a long pause.  Stopped with that one and moved on to another. You have to watch because they hire people that come from backgrounds in counseling. I asked for mediumship/psychic read and that is ne kept reverting to tarot.  A few didnt speak  English very well and it was hard to understand what they were trying to say.  (Broken English) they don’t screen them very well.  I ended up trying one more that was very good.  Didn’t offer any info she was unsure of.  Finally someone that didn’t B.S. me.  Their app is antiquated chat rooms. Can’t copy/paste or any basic or advanced features .  They would do well to actually test them before some of these folks are hired.  They need a different pricing schematic for sure.  Ive switched to another app.',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Expensive; not all psychics like they say they are',
#   'userName': 'B. S. Readers'},
#  {'date': datetime.datetime(2024, 6, 28, 22, 1, 14),
#   'developerResponse': {'id': 45075114,
#    'body': "Hello Dear Customer,\n\nThank you for sharing your feedback with us, although we're sorry to hear about your disappointment. We value your concerns and would like to address them. Firstly, we understand your frustration with the recent changes and the introduction of paid features. We apologize if this transition has affected your experience negatively.\n\nRegarding your privacy concerns, please rest assured that we take data security seriously. We do not sell user data to third parties, and users have the option to delete their data from our database if they choose to do so.\n\nAs for the availability of features, we have made changes to our subscription model to sustain the app's development and ensure continued service quality. We appreciate your feedback on pricing, and we continually review our pricing structure to provide fair value to our users.\n\nRegarding psychics, we assure you that all experts on our platform are real individuals with genuine expertise. If you have encountered any issues with the service quality, we apologize and would appreciate more details so we can investigate and improve.\n\nPlease contact us directly at nebula.support@nebulahoroscope.com so we can discuss your concerns further and assist you accordingly.\nThank you for your understanding and for sharing your thoughts with us.",
#    'modified': '2024-07-05T15:47:02Z'},
#   'review': '0 stars, if I could do negative starts I would. Just to start off, this is like 1 of 3 reviews I’ve ever made. This app has crumbled to pieces because they’ve been blinded by greed. I’ve used them for years for simple things like my birth chart and daily horoscope and the community but I knew this would happen when they started with the “ads to see match” and then took that away to begin charging for the “ideal partner” match compatibility feature. And slowly but surely everything started becoming unavailable unless subscribed. Now their charging to see a full birth chart. So they take our information put it in their database (to no doubt sell to other companies to scam or contact you without permission) and then make practically all areas in the app inaccessible unless you pay a ridiculous amount in subscriptions. Newsflash Nebula, you shot yourselves in the foot. And asking for more money (consistently) or saying you will “reduce the price” for a certain amount of time is just absurd and offensive. For what this app provides in “services” the cost is totally out of proportion and shows just how deluded pricing has gotten. This app is only interested in taking your money. And the “psychics” for the most part seem AI generated or illegible, but I don’t dabble in that enough to care. I’ll be uninstalling and will be actively telling people to avoid this app. It really is a shame, this app was such a great asset.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Worthless, and it’s Such a Shame Really',
#   'userName': 'ShamefulAppReviewer'},
#  {'date': datetime.datetime(2024, 11, 20, 11, 51),
#   'developerResponse': {'id': 48330761,
#    'body': 'Greetings dear Michaela!  \nThanks for your feedback.  \nIt is sad to hear about your negative user experience with our services. We are sorry for the payment troubles that happened.  \nContact us at nebula.support@nebulahoroscope.com so we can assist you in resolving the problem by logging into our payment system. We pledge to make use of all of the tools at our disposal to help you quickly find a fix for the problem.  \nHave a nice day, Nebula team 🔮',
#    'modified': '2024-11-19T07:44:43Z'},
#   'review': 'I don’t trust a company that purposefully sets you up to “accidentally” purchase a year premium membership and then makes you jump through hoops for a refund even though you cancelled immediately and have not used the app. There are many beautiful horoscope & astrology resources out there and encourage people to find one that actually care about people over money (especially when it comes to readings and energy work). \n\n Thanks for updating your response to be less of a gaslight, but everything I said still stands and your support team is useless and can do nothing about the scam that is this app. I’m confident that the majority of these positive reviews are fake to blend in with all the ones calling this out for being a cash grab. \n\n RESPONSE TO YOUR ORIGINAL REPLY BACK: 🙄pathetic. You all are delusional & condescending. Look at all your reviews and the comments discussing this app online…. your business model is to trick people into paying for things they did not intend to. I did in fact click to sign up for the free trial and then it changed to the yearly subscription anyways. I immediately exited out and cancelled within seconds and you were still unable and unwilling to easily refund me. Exactly how you’ve tricked hundreds of others it sounds like. Sad that you have to scam people into making money vs just having a good business. And you falsely charged me $50 again…',
#   'rating': 1,
#   'isEdited': True,
#   'title': 'Profit > People',
#   'userName': 'Michaelahe'},
#  {'date': datetime.datetime(2024, 2, 2, 2, 55, 18),
#   'developerResponse': {'id': 41721678,
#    'body': "Dear User, hello\n\nThank you for taking the time to share your thoughts on our app. We appreciate your kind words about the features and information provided.\n\nWe want to address your concerns regarding the pricing structure. Your feedback is valuable, and we're sorry to hear that the current model doesn't align with your expectations. We're constantly working to improve our services, and your input helps us understand areas for enhancement. \n\nTo ensure we provide a better experience for you and our users, we've taken note of your suggestion to offer longer, more reasonably priced sessions and to reduce interruptions during readings. These are insightful points, and we'll be reviewing our pricing model to find ways to make it more accommodating.\n\nWe genuinely care about your satisfaction, and we encourage you to contact us directly at nebula.support@nebulahoroscope.com with any further concerns or suggestions. Our team is here to assist you and enhance your experience with our app.\n\nThank you for being part of our community, and we look forward to serving you better in the future. Kindest regards, Nebula team 🔮",
#    'modified': '2024-02-03T09:20:06Z'},
#   'review': 'This app is very well made, and it is great for the daily horoscope and other information like your birth charts and much more information about you. However, I feel as if the prices for the readings are rooted in greed, and the paywall would be best for those making $100,000 per year or more. You get 3 minutes for free then every minute is 30-60 pts. 10 points is the equivalent of $1. So a ten minute conversation by text will cost you roughly $30. Not to mention the reading people will be on and off the conversation sometimes so you are occasionally paying while they are talking to someone else. This is definitely a critical issue. They need to rearrange the app to where you can schedule a 15ish minute reading for a reasonable price and have the reader exclusively. Some readers go up to 60 pts or $6 dollars a minute. I have local readings at a place that charges about $70 for 30 minutes. So I certainly feel like the prices on the app are quite excessive in my opinion. They are also basically sales people as random readers text me in the app every day to chat with them for money per minute. Decent app but a minute goes by instantly and it can take 2 minutes for them to even respond or look at your question.',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Good for daily horoscope, but readings feel rooted in greed.',
#   'userName': 'Bavis98'},
#  {'date': datetime.datetime(2025, 1, 11, 17, 52, 38),
#   'developerResponse': {'id': 49746585,
#    'body': 'Dear Customer,\r\nThank you once again for sharing your feedback with us — it means a lot. We sincerely apologize for the inconvenience you experienced with the Moon Calendar. Please rest assured that we’re already working on resolving this issue to ensure a better experience for you.\n\nPlease drop us a line at nebula.support@nebulahoroscope.com we’d love to hear from you and our team will gladly assist you. Your voice matters, and we’re here for you. :purple_heart:\r\nBest regards,\r\nThe Nebula Team',
#    'modified': '2025-01-17T19:43:12Z'},
#   'review': 'I have been using this app for YEARS, I’m the one in my friend group who forced my friends to download the app, and I check my horoscope on this app every single day it’s a routine. But every single update takes me one step closer to deleting the app forever. I hate the app now. It’s not cute, it’s not even fun anymore, it’s just ads. You give us one super vague annoying horoscope and that’s it, everything else is an ad. There used to be soo many fun features on this app that you guys have decided to take away. There’s no longer the moon phases and planets current location explanations like there used to me, or a few words at the top explaining what your focus of the day is, and if you want to look at your actual birth chart it’s impossible bc of all the ads you have to watch. Seriously rethink whatever team you have working on this app at the moment because you’re about to lose a lot of your “fans” to an app like co-star who instead of taking things away from us, is constantly adding new features',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'I’m annoyed',
#   'userName': 'annoyed and achey'},
#  {'date': datetime.datetime(2024, 8, 7, 14, 59, 43),
#   'developerResponse': {'id': 45860886,
#    'body': 'Greetings there!\nThank you for taking the time to leave us feedback.\n\nWe are sorry to hear that you didn’t enjoy our product.\nWe are sorry to hear that you had payment problems with our service, which caused your dissatisfaction.\n\nFeel free to contact our support service at nebula.support@nebulahoroscope.com (mailto:nebula.support@nebulahoroscope.com), so we could help you to solve this problem.\nBest regards, support team.',
#    'modified': '2024-08-09T03:26:56Z'},
#   'review': 'First of all, the app is really just about talking to psychics and not much about astrology or spirit animals or any of that like the ads claim. \n\nSecond, the app also makes you answer all these buzz feed quiz style questions and take a picture of your hand for a “palm reading” during the setup phase but never gives you the results of that.\n\nAnd finally, the biggest scam of all: at the end of all the questions and such, it forces you to pay before you can see the results (that don’t exist). But here’s the kicker: it initially tells you what the actual price is but if you can’t afford that, it gives you other prices you could pay including $1. I chose the $1 option because I couldn’t afford to pay full price nor do I want to before I’ve even seen the results. I ultimately decided the app wasn’t worth it so I deleted it. Well, a few days later I got a notification from my bank about this very app trying to charge me $45. So I blocked the charge and redownloaded the app and had to play around in settings for 10 minutes before I found the “how to check for active subscriptions” button  and entered in my email and discovered that the app had, in fact, signed me up for a subscription that I didn’t want. And it wasn’t even premium! I still had the option to sign up for premium because I didn’t have it. So what the h**l is the $45 for?',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'This app is a scam',
#   'userName': 'GenMimo'},
#  {'date': datetime.datetime(2025, 1, 16, 7, 35, 8),
#   'developerResponse': {'id': 49744104,
#    'body': 'Hello there!\nWe appreciate your feedback and comments!\nWe are sorry that payment problems with our service caused your dissatisfaction.\nPlease contact our support service at\xa0 (http://help.answers-365.com/)nebula.support@nebulahoroscope.com. We will do our best in order to solve your problems as soon as possible.\nHave a good day 🔮',
#    'modified': '2025-01-17T16:38:48Z'},
#   'review': 'This app is a scam and deceptive. They said you are trying a free trial. There is no way to see if you have a subscription in app or on web. I contacted support to cancel they send you a bot to try to talk too. They send you a link to cancel through Apple purchases, but they don’t show the trial at all until they sneakily charge you 45 dollars multiple times. It set off a fraud alert on my card and had to cancel it. I won’t have access to my bank account for over a week now until I get a new card. The customer service I finally did talk to were extremely rude and unhelpful. Saying that by taking any quiz you agreed to a 45 dollar charge and failed to cancel. Again sent me links to cancel, which I had already tried to do on my own the day I downloaded. There was in fact later a message saying I couldn’t cancel until my subscription was active. It wasn’t active until they sneak in the 45 dollar charge. This company is deceptive. I reported them fraudulent. I called Apple to deal with it and they had no proof I signed up for this subscription through Apple Pay. If I could give 0 stars I would. This is absolutely a scam. The “psychic” I messaged to cancel said they are sorry and paid so they have nothing to do with the app. TLDR: BEWARE DO NOT USE THIS APP IT CHARGES YOU FOR EVERYTHING WITHOUT WARNING AND YOU CANNOT CANCEL UNTIL THEY GET MULTIPLE CHARGES OF 45 DOLLARS FROM YOU.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Do not use this app',
#   'userName': 'd136637'},
#  {'date': datetime.datetime(2019, 9, 11, 16, 41, 27),
#   'developerResponse': {'id': 10644879,
#    'body': 'Thanks for your detailed review 💖\nThe Leo/Virgo issue fix is coming with the next update, please stay tuned. \n\nAnd as for compatibility reports, you get one for free a day. ',
#    'modified': '2019-09-12T07:53:24Z'},
#   'review': 'So my birthday is August 23rd, which I know is on a cusp. However, in the app it says August 23rd is a Virgo, yet it says I am a Leo in the app. I understand the whole cusp thing gives me qualities of both, but in the app it lists the beginning of Virgo as August 23rd, but yet it categorizes me as a Leo, which ends the 22nd? I definitely listed my birthday correctly. I don’t understand why it would categorize me as a Leo, when even in the app it begins Virgo on the 23rd? Is it a fluke? If you’re going to categorize me as a Leo, then at least change the dates you categorize with so there is at least an explanation. Don’t categorize me as a Leo, but then say Virgos start on the 23rd when you won’t even categorize me as a Virgo. \n\nAs for the app itself. The daily horoscopes are nice and even though it categorized me as a Leo instead of a Virgo, I was happy that I could still view the Virgo horoscope. As for the other features, you would have to pay to get anything else out of the app. Yes you get a free compatibility report, just one, if you wanted to try another you’d have to subscribe and pay. \n\nHonestly, I wish I could get past the Leo/Virgo issue I had, but it really bothers me and I think I’m going to have to delete the app. Please update your dates or fix the issue of having August 23rd-ers categorized as Leos when even in the app it says August 23rd is a Virgo.',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'An error right away?',
#   'userName': 'Ek2327'},
#  {'date': datetime.datetime(2024, 12, 22, 2, 45, 45),
#   'developerResponse': {'id': 48768399,
#    'body': 'Greetings there!  \nThank you for taking the time to leave us a review! It’s very important for us as it helps us to improve in order to provide you with more high-quality service!  \nWe are very sorry to hear that our app didn’t meet your expectations and that you had payment issues. We apologize for any confusion!  \nOur support service work all day long to help our customers, so you should definitely contact it at nebula.support@nebulahoroscope.com (mailto:nebula.support@nebulahoroscope.com) to get the solution of your problem.  \nBest regards, Nebula team 🔮',
#    'modified': '2024-12-07T01:59:40Z'},
#   'review': 'Wanted to love this app but btwn the bait n switch to get money from ppl and while in the app everything is nickeled and dimed I had the app for less than a day. Then had to deal with getting my money back in which of course it can be taken in seconds but getting it back is a diff story. Customer service is fine. As you can see on other complaints they will comment things are “clearly stated” however upon talking to customer service on insta having them admit to the app switching the choice to the 50 dollar option bc it’s “preferred” is an issue … there should be no switching from the persons original choice of the free trial etc right before the person moves forward. This is a clear trick and needs to be fixed if this isn’t unintentional… however I can imagine getting close to 50 bucks from multiple users wouldn’t be turned down regardless. In the end if you have the money floating for this app I guess it could be fun, but in todays world clarity and ease is what makes a strong app long term. I’m glad other ppl are enjoying it though.\n\nUPDATE: The response to this review is the perfect example of what is going on here, no accountability, no real solution. I have spoken to plenty of people from this company and they while nice are essentially not helping. Thankfully apple helped me in the end.',
#   'rating': 1,
#   'isEdited': True,
#   'title': 'Wanted to love it - feel duped',
#   'userName': 'ACD1987'},
#  {'date': datetime.datetime(2024, 11, 15, 3, 52, 35),
#   'developerResponse': {'id': 48266240,
#    'body': 'Greetings there!\n\nThank you for taking the time to leave us feedback  \nPlease accept our apologies for this inconvenience!  \n  \nWe have a big team of astrological advisors and developers working on this app daily, and their work has to be paid for. That is why Nebula has a paid subscription option without ads. However, our app also offers a lot of free, highly personalized content that you can easily access without a subscription.\n\nIf you have any questions feel free to contact our support service at nebula.support@nebulahoroscope.com, so we can help you to solve any problem.  \n  \nKind regards, Nebula team 🔮',
#    'modified': '2024-11-16T19:41:12Z'},
#   'review': 'I was looking for an easy app to use to have my birth chart information organized in a way that’s easy to read and navigate, there are plenty of websites that give you all this information for free, apps are just more convenient. Was entirely annoyed to see that literally EVERYTHING is locked behind a paywall besides very basic info like the sun, moon and rising signs that literally anyone can easily figure out with ten seconds of google. I get that it costs money to provide the convenience of this app and the services you host on it but jeez Louise you can’t find out a single freaking thing besides what your birth chart looks like and what your main planets are, literally everything else just teases you with a little snippet of text about it and locks it behind a paywall. I get paying for the readings and psychic services and like having a real person analyze your data but to not even let someone see the basic, established information about their planets and houses without paying is absolutely ridiculous. You’re not even going to let me look into basic information without paying for a subscription? Greeeeeeeeeeedy 🙄🙄 what a lame app',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Locking literally every piece of info behind a paywall is dumb and greedy',
#   'userName': 'skittleluvr'},
#  {'date': datetime.datetime(2020, 5, 15, 23, 53, 22),
#   'developerResponse': {'id': 32270069,
#    'body': 'Dear User, hello there! Thank you for taking the time to leave us a review! You can tell us more about your problem via our help center http://help.answers-365.com. It will be very helpful for us to investigate and fix it. Best wishes, Nebula team',
#    'modified': '2022-09-28T05:49:18Z'},
#   'review': 'BE VERY CAREFUL WHEN DOWNLOADING THIS APP. I signed up for the free trail but cancelled after I realized I wouldn’t be using it. I verified this under the subscription tab on my Apple account. HOWEVER, I soon started getting charged 9.99 WEEKLY from Apple and could not for the life of me find out where the hell these charges were coming from. Apple support could not help because they couldn’t see where the charge was coming from either and suggested that someone else in my household made the purchase. There is no one else connected to my account. I ended up moving all the money out of my bank account to avoid these charges. For months I’ve been inspecting every purchase I’ve made to see where it could be coming from. Finally after checking with my computer and cross referencing my phone purchases I see a Nebula weekly subscription charge for $0.00 4 days after the original purchase. Note that this charge does not show up on my iPhone X under purchases or subscriptions. After checking the app, I realized the in-app purchases add up with the random and constant attempts from apple to collect $9.99. As well as stating I am still subscribed to their weekly subscription. This subscription shows up as CANCELLED under my subscription tab and should be CANCELLED. This app is engaging in fraudulent and dishonest activities BEWARE.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'HIDDEN CHARGES WONT SHOW UP UNDER PURCHASES OR SUBSCRIPTIONS',
#   'userName': 'annifinn'},
#  {'date': datetime.datetime(2024, 10, 29, 21, 38, 35),
#   'developerResponse': {'id': 47231227,
#    'body': 'Hello, dear User!  \n  \nThank you for your review, and we’re truly sorry to hear about your experience.\xa0  \n  \nWe apologize for any confusion regarding our sign-up process and report delivery. It’s important to us that our users feel satisfied with our service. Please reach out to us at nebula.support@nebulahoroscope.com so we can review your case and address your concerns directly.\xa0  \n  \nWe appreciate your feedback.\n\nSincerely,\nNebula Team',
#    'modified': '2024-10-05T20:32:02Z'},
#   'review': 'I am so careful about fine print, but no matter what these guys absolutely are genius and tricking you with signing up. I did not sign up for a free trial. I did think that I was paying a small fee for a report that day. Of course I didn’t happen. I fell for the first time as well. Sad thing is I can’t find a report from anywhere in the app not on the Web through my account not in my emails. I’m sure they sent me something, \n\nThere’s no way they would still be in business otherwise. Anyhow, I did try chatting with a lovely bot this evening for the first time before I pursue canceling my $30 membership for I don’t know what It was entertaining and confirmed everything that I had been learning from my podcasts I probably would’ve considered staying with Nebula this time, but towards the end of a simple conversation of five minutes with the bot all of a sudden it turned into deposit more money to continue the conversation….',
#   'rating': 3,
#   'isEdited': True,
#   'title': 'Upped my stars due to the Customer service … but  doesn’t help the future peeps',
#   'userName': 'Mistifier33'},
#  {'date': datetime.datetime(2020, 5, 27, 3, 52, 22),
#   'developerResponse': {'id': 15868549,
#    'body': 'We are sincerely sorry about your negative experience with our product. We understand that $120 is not a small amount of money. However, it gives you an access to a large amount of highly-personalized content with a lifetime access . To provide you with this app , we have a big team of astrologists and developers working on it every day, and, of course, their work has to be paid appropriately. We hope you understand. Regarding the charging mechanisms of our application, we must assure you that they are in line with all App Store’s policies. Thank you for your understanding and have a great day!\nRegards,\nNebula Team',
#    'modified': '2020-06-09T08:39:41Z'},
#   'review': 'I accidentally selected membership instead of the 3 day free trial. There was not a clear way to select the option and I assumed the 3 day free period was standard. Unfortunately, when I confirmed, what I thought was the 3 day trial, the full membership option lit up and I was charged $127. I IMMEDIATELY contacted Nebula and explained what had happened. I also contacted Apple’s help center. I was told that I am, for reasons unknown, ineligible for a refund.  I’m extremely disappointed that I have been forced to pay such an incredibly large amount for this app. I signed up out of curiosity and am paying dearly for it. I am now stuck with either not using it and wasting my hard earned money, or using an app I DO NOT WANT.   I can assure you that when this unfair subscription has expired, I definitely will not renew and will take great care to make sure this company never receives another penny from me.\n\nI’ve read through many reviews and have come to the conclusion that Nebula is VERY aware that their subscription process is confusing and causing a lot of people to mistakenly lose out on a LOT of money. This is obviously intentional. They are obviously doing it because they know they Apple won’t require them to issue refunds. This is extremely dishonest and shows a complete lack of integrity.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Be extremely careful',
#   'userName': 'Funnybee101'},
#  {'date': datetime.datetime(2024, 11, 28, 9, 51, 37),
#   'developerResponse': {'id': 48595068,
#    'body': 'Hello dear Lynn\nThank you for your comment.\nWe are very sorry that you had such an unpleasant situation while using our platform.\nYou can tell us more details by email to our mail at nebula.support@nebulahoroscope.com and we will be able to provide you with a thorough explanation of your case and find a solution to your satisfaction.\nRespectfully, Nebula team 🔮',
#    'modified': '2024-11-29T23:25:49Z'},
#   'review': 'I have a subscription until December 2 but they already took it from me because I canceled it ( when I did it said it wouldn’t interfere with my subscription until it expired ) but because 7.99 weekly isn’t cheap for something that is not worth it! I can’t afford it every week . I’ve paid so much money already to this app just be able to read a horoscope on the phone and when it comes to the other stuff on here like the people who do the readings that cost soooo much that I pay 7.99 a week then I can’t even get a free reading ?? I can’t afford to look at the questions they want me to call the people that predict the future and tell me that I would want to ask them . ???? This app could be great , but they are greedy and don’t have a problem with taking your money , and  you get barely any more than you did before , and you still have to pay extra for stuff instead of paying for the whole thing so if I don’t have any more money to pay then they don’t even bother to leave it on the app for the remainder of my time left , instead they shut me down , and I know I have been a good dang customer and they don’t even care !!!! So no stars for me to you !!!!!  I’m',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Wow how I hate that this App is so dirty to people',
#   'userName': 'Curiosity Lynn'},
#  {'date': datetime.datetime(2024, 1, 1, 21, 6, 39),
#   'developerResponse': {'id': 40990581,
#    'body': "Hello Customer, We sincerely apologize for any inconvenience you've experienced, and we appreciate you bringing this matter to our attention. Your feedback is valuable to us. To address your concerns and resolve the issues you've encountered, we kindly ask you to contact our support team at nebula.support@nebulahoroscope.com. They will thoroughly investigate the situation and work towards a satisfactory resolution. We understand the importance of trust and transparency, and we want to assure you that your concerns will be taken seriously. If you have any additional details or specific incidents you'd like to share, please include them in your email to our support team. Thank you for your understanding, and we look forward to assisting you promptly! Best regards, Nebula Team.",
#    'modified': '2023-12-30T18:29:22Z'},
#   'review': 'I had to cancel a debit card because of this company. Not only that but I had to go to the bank and the bank had to flag the 3 attempts of false charges, because after opting out and deciding against the app subscription.. they still attempted to charge my bank account 3 times. All day I didn’t have access to my money in my account, had to change my debit card number and wait for it to be mailed to me, because of this company. I understand the need to pay for something if it is worth it, but this app/company isn’t worth the risk. **with the amount of reviews of STOLEN money from people, I truly HOPE they get sued and shut down.\n /update for the developers response./ I will not be contacting any “support team,” from this company. For all I know clicking on that website alone will result in another false charge. My bank is investigating the charges and I was assured they filed three separate police reports for the fraudulent attempts on my bank account. It is evident that this isn’t a horoscope app, it’s a front to steal money from innocent people. You take advantage of people’s curiosity and like I’ve said previously, I hope the company is sued and permanently banned.',
#   'rating': 1,
#   'isEdited': True,
#   'title': 'Scammer/fraud',
#   'userName': 'sosbeukjhdstffjkloudd'},
#  {'date': datetime.datetime(2023, 6, 20, 23, 51, 58),
#   'developerResponse': {'id': 37273888,
#    'body': 'Dear BigBLittle, hello there!\r\n\r\n\nWe are doing our best to make you enjoy our service, so it is really hard for us to hear that you didn’t like our service.\r\n\r\n\nPlease contact us at http://help.answers-365.com and tell us more about the problem with our app. This information will greatly help our tech team to fix the confusion fast, so you could get back to normal usage of our service.\n\r\n\r\n\nRespectfully, Nebula team 🔮\r\n\r',
#    'modified': '2023-06-22T14:39:09Z'},
#   'review': 'I would love this app but the chatting forum and direct messaging are screwed. I can hardly write a post, comment on other’s posts, or send direct messages because I keep getting “Unknown Error: Message contains inappropriate data” when I don’t say anything derogatory, I don’t say anything personal, I don’t say anything hateful or hurtful, and I don’t say anything offensive. There’s no reason for my messages, comments, or posts to be blocked but they get blocked very often and it’s very annoying. There are many times I try to help people who make posts about stuff they are struggling with and I can’t say anything positive or helpful because it gets blocked for “inappropriate data” without any indication of what is inappropriate and I reread what I wrote and see nothing inappropriate at all! Someone needs to fix this because I’m sure it’s common words that someone who wrote the rules for posting/commenting/messaging marked as inappropriate when these words, common everyday words, are not inappropriate in any way shape or form. If this issue gets fixed I’ll change my review from 2 star to 5 star.',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Messages and Posts',
#   'userName': 'BigBLittle'},
#  {'date': datetime.datetime(2021, 7, 7, 19, 6, 7),
#   'developerResponse': {'id': 23903776,
#    'body': 'Dear User, hello there!\r\n\r\nWe are very sorry to hear that our app didn’t meet your expectations and that you had payment issues. We apologize for any confusion!\r\nIf you have received a bank payment notification on the website, it means that you have activated automatic renewal. You confirm the automatic subscription renewal during the first payment for the Premium Subscription or Compatibility Report along with the Premium Subscription.\r\nWe provide this information on our sales page, payment screen, and Subscription terms. Also, in the Subscription Terms, it is clearly stated how to cancel the website subscription.\r\nPlease get in touch with us at support.nebula@gen.tech, we will do our best to help you with this concern.\r\n\r\n',
#    'modified': '2021-07-13T11:39:42Z'},
#   'review': 'I agreed to the free 7-day trial, on the 6th day, I could not find the unsubscribe link, so I emailed. Andrew” told me my request was received, and that I am now unsubscribed. After that, I was charged $9.99 three times. I emailed them about this, and they told me I did not unsubscribe in time, and that the subscription link was sent to me in an email, I should have used that to unsubscribe. I never received this link. All I could find in my emails is the support email. But they kept telling me I need to use this non-existent link. I went back-and-forth with them through e-mail, and all the while they were telling me that I cancelled too late and I am not entitled to a refund. This morning I got my fourth charge from them. They still have not cancelled my “subscription” which I never signed up for, nor have they sent me this link they kept telling me I received, which I didn’t. \n\nI now will have to contact my credit card company and  hope they will do something about it. \n\nDo not down load this app, unless you want serious headaches down the line. Read the other reviews, they corroborate this horrible experience and terrible customer service.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'DO NOT DOWNLOAD THIS APP!!!',
#   'userName': 'Yvette Me'},
#  {'date': datetime.datetime(2024, 3, 4, 9, 38, 46),
#   'developerResponse': {'id': 42398721,
#    'body': "We're thrilled to hear you're enjoying the app and finding it accurate! Your feedback is valuable, and we'll consider incorporating more detailed explanations for chart items like modality percentages in future updates. Thank you for your support and enthusiasm!",
#    'modified': '2024-03-06T00:37:05Z'},
#   'review': 'As freakily accurate as the chart is, I am just now discovering there are various many other things that are taken into account—like your Pallas Sign among one…\n\nI paid for the lifetime thing and I hope that eventually in the future you include more of the other various miscellaneous things besides the planets!\n\nI’m excited to find out more!\n\nAlso, if there is a way to include more info on some of the chart items like with the significance of the percentages for modality and also elements and fem/masc thing? Like maybe if I long pressed on the little percentage chart it could explain it more? Possibly? For example, it says I am a fixed sign under traits (I’m an Aquarius!) but doesn’t explain the significance of my modality actually having the largest percentage in mutable?\n\nOtherwise. I love this app a lot and I showed my chart to my friends and they were astounded at how scarily accurate its description of me was.\n\nI also (sorry I’m asking for so much stuff, but I will use this app for as long as you exist!!!) would love to possibly see in the future a section that can kinda summarize our overall strengths but also areas we may have a tendency to be weak in or areas to be on the lookout for to focus on for enhanced personal growth!\n\nPlease and thank you, Nebula Team!\n\nKeep up the good work and love the app!!!',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'GlenjaminRex',
#   'title': 'Love the insight but…'},
#  {'date': datetime.datetime(2021, 2, 1, 19, 39, 54),
#   'developerResponse': {'id': 20840138,
#    'body': 'Thanks a lot for sharing your experience with the Nebula app.',
#    'modified': '2021-02-03T17:52:38Z'},
#   'review': 'This is peak astrology right here. General life advice posing as specific fortune telling? Check. Mystical sounding words that are never explained? Check. A roll of the dice to see if your partner actually loves you today? Check. Whatever a biorhythm is? Check. The nebulatalk tab is a riot. I can waste hours reading people explain their real issues and then someone being like “Oh! Thats because Venus is prolapsing today 😌” as if that means anything. Don’t try to read it if you’re not prepared for some nigh-on incomprehensible  grammar (not hyperbole, I think most of the users are having a constant stroke), but it makes it funnier if you’re prepared. 10/10 entertainment value if you like laughing at people who think this is real. I would give 5 stars, but 1 star has been removed for only including male and female in the gender select screen. I’m not surprised that people who think balls of gas billions of miles away determine your fate also believe in the gender binary, but I’m still docking points.',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'Firegirl1064',
#   'title': 'Absolutely hilarious'},
#  {'date': datetime.datetime(2025, 1, 4, 15, 0, 16),
#   'developerResponse': {'id': 49409525,
#    'body': 'Greetings there!\nWe greatly appreciate your time to leave a review.\nWe are sorry to hear about your negative experience with Nebula.\nFeel free to contact our support service at nebula.support@nebulahoroscope.com, so we could help you to solve this problem.\nBest regards, Nebula team 🔮',
#    'modified': '2025-01-05T21:43:32Z'},
#   'review': 'I struggle to find anything good about this app. There’s absolutely nothing of value. Nothing at all. Three minutes free with the psychic and it just didn’t even work or function. The horoscopes were written by a stoned College kid or something ridiculous. It’s also political. Support Ukraine. What’s next? Support support you support them support everybody. How about if someone wants to hear political position on stuff will ask for it. I’ll tune into a channel and specifically seek it out or bottom line. It’s just such a letdown. There’s not one element of the app that’s worthy of praise. Not structurally there’s no flow things are scattered. I don’t really know what it’s got going on. I had high hopes for it. It’ll let you down. It’ll break your heart. It’ll be the equivalency or far worse than the sequel to point break the remake. It won’t pleasantly surprise you. But I’m all about keeping the economy going and helping these fine people who at least put an effort into creating something. I’m sorry I’m trashing it. But spend money there a little bit and give it a whirl and make your own determination.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'MoundSwagga',
#   'title': 'Colossal waste of time'},
#  {'date': datetime.datetime(2021, 10, 27, 23, 15, 45),
#   'developerResponse': {'id': 25959334,
#    'body': 'Dear User, hello there!\nThank you so much for your feedback, we appreciate it so much! It is users like you that keep pushing us to deliver the best customer experience, while at the same time making our job enjoyable. Please email us at support@nebulahoroscope.com for assistance in solving any issues you may have had.\nBest wishes, Nebula team\n',
#    'modified': '2021-10-29T04:27:36Z'},
#   'review': 'It is an amazing app as far as the chart, advise, and reading aspect of it goes and I would give that part alone a 5 star rating but I simply can’t with the social media side included in the calculation of my opinion on the app. It’s just insanely hard to navigate. I think you should have a notification box set-up to make it easier to see responses to your comments and comments on your post. I also think you should be able to click on someone’s profile and see their other posts. Finally, I think you should be able to search (by key word) for people and posts. In addition to that, I think you should be able to edit your profile picture and maybe even add friends/make friend requests but these things wouldn’t help with the overall working of the app (I think it would improve the experience though).',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'JRC030608',
#   'title': 'Social media side'},
#  {'date': datetime.datetime(2020, 3, 15, 20, 0, 55),
#   'developerResponse': {'id': 14112873,
#    'body': "Wow, thanks for your feedback! \nWe're really glad you like Nebula, this keeps us going\n💖",
#    'modified': '2020-03-19T09:01:48Z'},
# ...
#    'modified': '2024-03-06T19:17:27Z'},
#   'review': 'Let me clarify two things, one being, I have NEVER felt the need to write a review on an app so horrible. TWO, I have been a spiritual person all my life thinking this app would help me connect and become more in tune with myself. I have never been more wrong. After spending 10 dollars on a psychic evaluation, I was left with the most dull, unprofessional responses I have ever read. I spent TEN DOLLARS, on a one minute session that granted no sense of comfort. The “psychic” did not even answer my one question that I had the time to ask. Feeling disappointed, I tried leaving a review under the ladies profile and couldn’t. Be warned, this app is money hungry and infested with ads. If you truly want to know more about your horoscopes and astrology I would recommend reading online or picking up some books. Reach out to a PROFESSIONAL psychic and not some pretentious wannabes.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Ilovegamesnomaterwhat',
#   'title': 'Stole my money/ FAKE GARBAGE'},
#  {'date': datetime.datetime(2023, 6, 27, 0, 0, 12),
#   'developerResponse': {'id': 37376726,
#    'body': 'Greetings there! Thanks for telling us your opinion on the matter of our service.\n\nIt is sad to hear about your negative user experience with our product.\n\nPlease tell us more about the situation at http://help.answers-365.com. Your additional information will help our support team to resolve an issue rapidly and let you enjoy being a part of Nebula family. Best wishes, Nebula team 🔮\n\n',
#    'modified': '2023-06-28T09:18:24Z'},
#   'review': 'the app is fine. it’s just fine. it’s like any other app you can buy, slightly worse than just a regular online website that talks about your chart. they only base things around your sun sign although you do get a (incredibly brief talking like 2 sentences each house) reading. it’s definitely “accurate” because of how ambiguous it is and the relationship reading isn’t at all telling. they give you a free $3 relationship reading then make you wait 3 days (when the trial period ends of course) for the reading and if you cancel ur membership it before those three days then they cancel your reading as well. the reading itself is literally laughable. 3 days for an ai generated report ONLY on your sun sign. if ur a astrology baby who loves apps like this don’t get this one, web sites will give you everything this app can’t.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'mythicsfrosty',
#   'title': 'not worth paying for sure'},
#  {'date': datetime.datetime(2022, 1, 9, 5, 55, 38),
#   'developerResponse': {'id': 27363711,
#    'body': 'Dear User, Hello!\n\nThank you very much for your feedback! It is very important for us to hear from our users and we will definitely consider your great idea.\n\nIf you have any other suggestions on how we can improve our application, please contact us http://help.answers-365.com, we will be glad to talk with you.\n\nBest regards, Nebula team',
#    'modified': '2022-01-11T06:06:11Z'},
#   'review': 'Heyy, so the app is pretty good. My only plight is the Nebula talk feeds and stuff. Please make it to where, we have an actual profile and we get notifications on our post and can actually go to them. I notice when I get a notification it takes me to the entire feed and I have to find my post. The community should be an actual community where we can have small profiles with our pictures so we know who we’re talking to at least. Also, if you can make it to where we can post videos as well and bigger picture sizes. Please fix the community part of the app. It’s frustrating trying to find your post and it limits what you can actual say or see.',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'onyxmiamoure',
#   'title': 'PLEASE FIX THESE'},
#  {'date': datetime.datetime(2024, 8, 24, 13, 33, 46),
#   'developerResponse': {'id': 46251438,
#    'body': "Hello dear user!\nThank you for your feedback. We're sorry to hear about your experience. We’re constantly working to improve our services.\xa0\nAlso, please reach out to our support team regarding any questions you may have at support@nebulahoroscope.com.\nBest regards, Nebula Team 🔮",
#    'modified': '2024-08-26T05:25:05Z'},
#   'review': 'The app is very repetitive. Advisors are frequently not online and nonresponsive. It is a very expensive app to use for simply a few minutes you’re better to work with local advisors or someone you already have established. The support team is like a chat where you still have to wait for the next person to respond to you via email. I purchased credits from a wheel that you have the opportunity to each day and there is nowhere to find your balance. It is very cumbersome and redundant. The language on every horoscope or relationship guide is usually the same thing every day it does not change. Whoever writes their programming, is getting paid to never update, what users pay for. Do not waste your money on this app to pay for any other upgrades.',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'Norzz',
#   'title': 'Not as expected'},
#  {'date': datetime.datetime(2024, 4, 2, 2, 51, 38),
#   'developerResponse': {'id': 43023950,
#    'body': "Hello, dear User. \n\nThank you for sharing your feedback with us regarding your experience with our advisors.\n\nWe sincerely apologize for any frustration or inconvenience caused by the pricing structure and timing issues you've encountered during your readings. Your satisfaction is important to us, and we appreciate your valuable input as we continuously strive to improve our services.\n\nWe understand the importance of timely responses during chat readings and the impact it can have on your credits. We kindly ask you to reach out to our support team at nebula.support@nebulahoroscope.com. Our team is here to assist you and address any issues you may have encounter promptly.\n\nThank you for bringing this to our attention, and we apologize for any inconvenience you've experienced. We hope to have the opportunity to regain your trust in the future.\n\nBest regards,\n\nNebula Team 🔮",
#    'modified': '2024-04-03T11:43:56Z'},
#   'review': 'Looks like the average pricing for a reading is about $5 a minute depending on the advisor. The readings are via a chat room. So, if the advisor responds slowly, you will lose money. So far, one of the advisors is very prompt in responding. However, you need to make sure that you reach out to them while they are online. The site does give you an option of texting the advisor while they are offline and reportedly will respond to you when they are online again. The issue is that if they respond and you aren’t available, they use up all your credits because the timer starts once they respond. I’ve lost 200 credits because one of the advisors responded when I wasn’t near my phone and she let the timer run. I wasted all my credits for her to ask me “I need a first name”. Will not used again until this is fixed.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'miiiiiiiiiiniiiiiiiiii',
#   'title': 'Waste of money'},
#  {'date': datetime.datetime(2020, 7, 1, 16, 5, 56),
#   'developerResponse': {'id': 16451378,
#    'body': 'Thank you for your feedback, and we are sincerely sorry for the inconvenience. We have just released an update in which this issue is fixed. Please try updating Nebula to get rid of this pop-up.',
#    'modified': '2020-07-07T07:03:01Z'},
#   'review': 'I genuinely love this app. The information it provides is pretty detailed and accurate, and the UI is amazing and easy to navigate. I also like that you don’t necessarily need to sign up for an account, it just uses your birth information.\n\nThe reason I have to give it 2 stars is because no matter where I go, I will always get a full screen prompt to download the companion messages stickers app literally every 5 seconds even after dismissing it. It literally makes the app unusable when I can’t even load certain information because I get a full screen prompt asking to download this companion app over and over again. This happens even after force quitting and deleting/reinstalling the app. Hopefully the next update fixes it and it isn’t a wide spread issue. I’d love to continue using this app if I can!',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'DifferentSon',
#   'title': 'Great app bogged by big problem'},
#  {'date': datetime.datetime(2020, 3, 1, 15, 58, 35),
#   'developerResponse': {'id': 13799162,
#    'body': 'Thanks for your feedback! ',
#    'modified': '2020-03-02T09:12:39Z'},
#   'review': 'First- On the initial screen, my birthdate is incorrect. However when I swipe to the next screen it is listed correctly. And there is no “settings” that I can find on the app to fix this. This misinformation could have a detrimental effect to my reading. \nSecond- I’m not sure what I’m paying for. I’m not impressed with the information I’m being given that is not available through other places. You’ve offered me no additional insight about myself, my compatibility, my planets, etc, that I didn’t already know. \nThird- I wanted the relationship info. It said the report would be ready. But it’s a breadcrumb trail released by days to keep people paying for 4 weeks. However, there is no way for me to go back when I missed a day or go forward and read the next day. That’s a waste of my time and money. \n\nI’m disappointed. And I’m canceling. Not even 1 star.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Love2Bmomma',
#   'title': 'Waste. Do your own research for free.'},
#  {'date': datetime.datetime(2020, 1, 8, 0, 55, 11),
#   'developerResponse': {'id': 12814664,
#    'body': "Thanks for your review. We're really happy you like Nebula and our haircut calendar. \nThere was a temporary issue with the calendar, now it's back, enjoy! ",
#    'modified': '2020-01-09T10:07:32Z'},
#   'review': 'I really enjoy this app. I appreciate the positive horoscopes. I do think that it is way too expensive for premium, however it’s a pretty cool app. Honestly love everything about it, especially the haircut calendar. That is something unique that I’ve never seen on a horoscope app before. This is my favorite feature, but it’s been missing for the the new year. I’ve given it a couple days, hoping that it will show up. I even tried the free trail, looking to see if it was a premium thing (which I would/could never stomach paying that much)... which I’m really hoping that it’s not. Is there something wrong with it? Will it be released for the new year? Please let me know! Please don’t get rid of it! Please keep it as a free feature, it will draw a lot more customers!',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'seasickcr0c',
#   'title': 'Pretty cool astrology app'},
#  {'date': datetime.datetime(2025, 1, 14, 5, 29, 46),
#   'developerResponse': {'id': 49746558,
#    'body': 'Dear Customer,\r\nGreetings there! :star2:\r\nThank you once again for sharing your feedback with us — it means a lot. We sincerely apologize for the inconvenience you experienced with the Moon Calendar. Please rest assured that we’re already working on resolving this issue to ensure a better experience for you.\r\nPlease drop us a line at nebula.support@nebulahoroscope.com we’d love to hear from you and our team will gladly assist you. Your voice matters, and we’re here to make things right for you. :purple_heart:\r\nBest regards,\r\nThe Nebula Team',
#    'modified': '2025-01-17T19:41:12Z'},
#   'review': 'I’m only giving two stars because of how much I used to love this app, with these changes, they deserve one star. This was one of my beloved apps that i used for astrology they changed the whole interface, they removed masculine, and feminine energies which made this app unique that they told you if you were more dominant, and either one. That was one of my favorite features about this app specifically then they decided to remove the moon cycle and what phase the moon is in which again is another feature that I really loved about this app. These features are what made this app different than the others. And now it just looks so generic and it’s so disappointing. Please bring back these features. I know I’m not the only one that loved how unique this app used to be.',
#   'rating': 2,
#   'isEdited': False,
#   'userName': 'roseabusaad',
#   'title': 'They ruined this app'},
#  {'date': datetime.datetime(2020, 1, 17, 13, 45, 19),
#   'developerResponse': {'id': 13010264,
#    'body': "We have about a million of happy users with about 13,000 5-star reviews. \nUnfortunately sometimes the issues like yours happen. We always respond to this issue and do everything possible to help with the issues. If you need any other assistance, please drop us an email at nebula@gen.tech \n\n\nAs for your question ho to cancel your subscription. Deleting an app doesn't cancel your subscription. \nPlease follow this steps to check your subscription status and cancel it, if it's still active: \nOpen Settings → [your name] → Subscriptions on your iPhone.\n\nThere you will see a list of all active and expired subscriptions. When you tap on a subscription from the list, you can choose a different subscription option or tap Cancel Subscription.\n\nIf you don’t see Cancel Subscription, the subscription is already canceled and won't renew. \n\nHere's a more detailed guide on that from Apple:\xa0\nhttps://support.apple.com/en-us/HT202039",
#    'modified': '2020-01-20T09:00:58Z'},
#   'review': 'I NEVER do reviews, but I was motivated enough to do one now. Anyways, you should read all of the One Star reviews if you’re thinking about getting this app—-there’s quite a few of them, and they are ALL about how THIS APP STEALS MONEY!! I got it and opted for the three days trial and instantly disliked it. It was nowhere near to accurate. When I tried to get out of the free trial it wouldn’t let me. There’s literally NO SETTINGS on this app, so I had no idea how to unsubscribe, I even tried deleting the app from my phone, by this time it had already charged me. I had to look online for like twenty minutes before I could figure out how to unsubscribe. By then I’d already been charged. Again. I unsubscribed AND IM STILL GETTING CHARGED FOR IT!!!!!!! I don’t even have the app anymore!!! You’d think after so many bad reviews the creators would have done something. Why haven’t they? Because they’re getting free money.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'Zay1234567890987654321',
#   'title': 'THEY WILL STEAL YOUR MONEY.'},
#  {'date': datetime.datetime(2020, 12, 9, 5, 3, 36),
#   'developerResponse': {'id': 19691832,
#    'body': 'Hello, thank you a lot for your comment and for your suggestions. Our Developers put maximum effort to improve our app and make it suitable and convenient for the users. We appreciate your understanding.',
#    'modified': '2020-12-11T08:31:10Z'},
#   'review': 'It’s a nice app but my only issue is the gender selection it is only male and female. There are far more genders than two and if you disagree go ask a scientist. Anyways there should be at least an other choice or maybe custom option. Also as afab (a female at birth I put female bc I just wanted to try the app) when there is mentioning of relationships it was assumed as he bc I put female. Just so ya know creators not everyone likes the opposite gender. To solve this you could use they/them bc it is neutral. Although this could be very small to some people making it normalized on the most random apps are playing a part in something that is natural. If you don’t think it is natural ask yourself what’s the definition of natural? Then use google and look up homosexual behaviors in other species.',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'ec.2',
#   'title': 'I have a suggestion'}]

# %%
df = pd.DataFrame(reviews)
df.head()
# Out:
#                  date                                  developerResponse  \
# 0 2019-10-05 23:30:44  {'id': 11098150, 'body': 'Thanks for your revi...
# 1 2019-10-05 23:27:49  {'id': 11098037, 'body': 'It's so kind of you,...
# 2 2019-10-05 23:27:35  {'id': 11098029, 'body': 'Appreciate your feed...
# 3 2024-11-22 11:43:24  {'id': 48445622, 'body': 'Hello dear user!
#  ...
# 4 2024-06-28 22:01:14  {'id': 45075114, 'body': 'Hello Dear Customer,...
#
#                                               review  rating  isEdited  \
# 0  Crazy accurate!!! I am not sure who writes the...       5     False
# 1  I really like getting my daily horoscope in th...       5     False
# 2  Nothing but great things to say about this app...       5     False
# 3  I went through a bunch of psychics before i fo...       5     False
# 4  0 stars, if I could do negative starts I would...       1     False
#
#                                                title             userName
# 0                                               Anna          Uz3-155-597
# 1                                               Alex             m8fjl5VA
# 2                                              Tanya             Сцукатик
# 3  Expensive; not all psychics like they say they...        B. S. Readers
# 4            Worthless, and it’s Such a Shame Really  ShamefulAppReviewer

# %%
df["cleaned_review"] = df["review"].str.lower().str.replace(r'[^\w\s]', '')
df["cleaned_review"] = df["cleaned_review"].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df.head()
# Out:
#                  date                                  developerResponse  \
# 0 2019-10-05 23:30:44  {'id': 11098150, 'body': 'Thanks for your revi...
# 1 2019-10-05 23:27:49  {'id': 11098037, 'body': 'It's so kind of you,...
# 2 2019-10-05 23:27:35  {'id': 11098029, 'body': 'Appreciate your feed...
# 3 2024-11-22 11:43:24  {'id': 48445622, 'body': 'Hello dear user!
#  ...
# 4 2024-06-28 22:01:14  {'id': 45075114, 'body': 'Hello Dear Customer,...
#
#                                               review  rating  isEdited  \
# 0  Crazy accurate!!! I am not sure who writes the...       5     False
# 1  I really like getting my daily horoscope in th...       5     False
# 2  Nothing but great things to say about this app...       5     False
# 3  I went through a bunch of psychics before i fo...       5     False
# 4  0 stars, if I could do negative starts I would...       1     False
#
#                                                title             userName  \
# 0                                               Anna          Uz3-155-597
# 1                                               Alex             m8fjl5VA
# 2                                              Tanya             Сцукатик
# 3  Expensive; not all psychics like they say they...        B. S. Readers
# 4            Worthless, and it’s Such a Shame Really  ShamefulAppReviewer
#
#                                       cleaned_review
# 0  crazy accurate i am not sure who writes these ...
# 1  i really like getting my daily horoscope in th...
# 2  nothing but great things to say about this app...
# 3  i went through a bunch of psychics before i fo...
# 4  0 stars if i could do negative starts i would ...

# %%
result = calculate_metrics(df)
result
# Out:
# {'average_rating': '2.44',
#  'rating_distribution': {1: 45.0,
#   5: 17.0,
#   3: 14.000000000000002,
#   2: 12.0,
#   4: 12.0}}

# %%
sentiments = analyze_sentiment(df.to_dict(orient="records"))
df["sentiment"] = [s["sentiment"] for s in sentiments]
df.head()
# Out:
#                  date                                  developerResponse  \
# 0 2019-10-05 23:30:44  {'id': 11098150, 'body': 'Thanks for your revi...
# 1 2019-10-05 23:27:49  {'id': 11098037, 'body': 'It's so kind of you,...
# 2 2019-10-05 23:27:35  {'id': 11098029, 'body': 'Appreciate your feed...
# 3 2024-11-22 11:43:24  {'id': 48445622, 'body': 'Hello dear user!
#  ...
# 4 2024-06-28 22:01:14  {'id': 45075114, 'body': 'Hello Dear Customer,...
#
#                                               review  rating  isEdited  \
# 0  Crazy accurate!!! I am not sure who writes the...       5     False
# 1  I really like getting my daily horoscope in th...       5     False
# 2  Nothing but great things to say about this app...       5     False
# 3  I went through a bunch of psychics before i fo...       5     False
# 4  0 stars, if I could do negative starts I would...       1     False
#
#                                                title             userName  \
# 0                                               Anna          Uz3-155-597
# 1                                               Alex             m8fjl5VA
# 2                                              Tanya             Сцукатик
# 3  Expensive; not all psychics like they say they...        B. S. Readers
# 4            Worthless, and it’s Such a Shame Really  ShamefulAppReviewer
#
#                                       cleaned_review sentiment
# 0  crazy accurate i am not sure who writes these ...  positive
# 1  i really like getting my daily horoscope in th...  positive
# 2  nothing but great things to say about this app...  positive
# 3  i went through a bunch of psychics before i fo...  positive
# 4  0 stars if i could do negative starts i would ...  positive

# %%
generate_visualizations(df)
# Out:
# 2025-01-31 17:25:16,822 [INFO] matplotlib.category - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# /var/folders/sb/296x26_j7pg_3zdg9y9ccvv40000gn/T/ipykernel_72041/69507975.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['rating'], palette='viridis')
# 2025-01-31 17:25:16,826 [INFO] matplotlib.category - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
csv_file = generate_csv(reviews)
csv_file
# Out:
# 'reports/reviews.csv'

# %%
insights = generate_insights(df.to_dict(orient="records"))
insights
# Out:
# {'common_negative_phrases': [('i', 164),
#   ('this', 69),
#   ('it', 65),
#   ('app', 64),
#   ('my', 63)],
#  'suggested_improvements': []}
